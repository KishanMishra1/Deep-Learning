# %% [markdown]
# <a href="https://colab.research.google.com/github/KishanMishra1/Deep-Learning/blob/main/Social_Media_Followers_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data = pd.read_csv("https://raw.githubusercontent.com/KishanMishra1/Datasets-Here/main/stats.csv")

# %%
data.drop(data.tail(1).index, inplace=True)
data.head()
# Out:
#   period_start period_end  ...  subscribers_total    views
# 0     5/1/2020  5/31/2020  ...                  0    128.0
# 1     6/1/2020  6/30/2020  ...                  0  16130.0
# 2     7/1/2020  7/31/2020  ...                  0  14616.0
# 3     8/1/2020  8/31/2020  ...                  0   4053.0
# 4     9/1/2020  9/30/2020  ...                  0   5153.0
#
# [5 rows x 11 columns]

# %% [markdown]
# **Number of followers that I gained every month**

# %%
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Number of Followers I Gained Every Month")
sns.barplot(x="followers_gained", y="period_end", data=data)
plt.show()

# %% [markdown]
# **Total number of followers I end up with every month.**

# %%
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Total Followers At The End of Every Month")
sns.barplot(x="followers_total", y="period_end", data=data)
plt.show()

# %% [markdown]
# **Total number of views I get each month**

# %%
plt.figure(figsize=(15, 10))
sns.set_theme(style="whitegrid")
plt.title("Total Followers At The End of Every Month")
sns.barplot(x="followers_total", y="period_end", data=data)
plt.show()

# %%
pip install autots
# Out:
# Collecting autots
#   Downloading AutoTS-0.3.10-py3-none-any.whl (437 kB)
#      |████████████████████████████████| 437 kB 7.6 MB/s
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from autots) (1.19.5)
# Requirement already satisfied: pandas>=0.25.* in /usr/local/lib/python3.7/dist-packages (from autots) (1.1.5)
# Requirement already satisfied: scikit-learn>=0.20.* in /usr/local/lib/python3.7/dist-packages (from autots) (0.22.2.post1)
# Requirement already satisfied: statsmodels>=0.10.* in /usr/local/lib/python3.7/dist-packages (from autots) (0.10.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.*->autots) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.*->autots) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.*->autots) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.*->autots) (1.1.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.*->autots) (1.4.1)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.10.*->autots) (0.5.2)
# Installing collected packages: autots
# Successfully installed autots-0.3.10

# %%
from autots import AutoTS
model = AutoTS(forecast_length=4, frequency='infer', ensemble='simple')
model = model.fit(data, date_col='period_end', value_col='followers_gained', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
# Out:
# Inferred frequency is: M
# Model Number: 1 with model AverageValueNaive in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model DatepartRegression in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# Epoch 1/50
# 1/1 [==============================] - 5s 5s/step - loss: 0.3863
# Epoch 2/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3748
# Epoch 3/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3722
# Epoch 4/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3578
# Epoch 5/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3639
# Epoch 6/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3724
# Epoch 7/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3627
# Epoch 8/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3471
# Epoch 9/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3609
# Epoch 10/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3665
# Epoch 11/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3643
# Epoch 12/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3747
# Epoch 13/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3625
# Epoch 14/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3480
# Epoch 15/50
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3590
# Epoch 16/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3799
# Epoch 17/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3596
# Epoch 18/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3477
# Epoch 19/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3486
# Epoch 20/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3528
# Epoch 21/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3555
# Epoch 22/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3506
# Epoch 23/50
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3548
# Epoch 24/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3568
# Epoch 25/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3434
# Epoch 26/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3607
# Epoch 27/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3392
# Epoch 28/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3359
# Epoch 29/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3478
# Epoch 30/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3414
# Epoch 31/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3496
# Epoch 32/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3391
# Epoch 33/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3269
# Epoch 34/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3482
# Epoch 35/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.3367
# Epoch 36/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3314
# Epoch 37/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3396
# Epoch 38/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3314
# Epoch 39/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3435
# Epoch 40/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3389
# Epoch 41/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3235
# Epoch 42/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3399
# Epoch 43/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3287
# Epoch 44/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3181
# Epoch 45/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3061
# Epoch 46/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3165
# Epoch 47/50
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3310
# Epoch 48/50
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3064
# Epoch 49/50
# 1/1 [==============================] - 0s 17ms/step - loss: 0.3068
# Epoch 50/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3035
# Model Number: 8 with model ETS in generation 0 of 10
# Model Number: 9 with model ETS in generation 0 of 10
# Model Number: 10 with model GLM in generation 0 of 10
# Model Number: 11 with model GLM in generation 0 of 10
# Model Number: 12 with model GLS in generation 0 of 10
# Model Number: 13 with model GLS in generation 0 of 10
# Model Number: 14 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 14: GluonTS
# Model Number: 15 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 15: GluonTS
# Model Number: 16 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 16: GluonTS
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 19: GluonTS
# Model Number: 20 with model LastValueNaive in generation 0 of 10
# Model Number: 21 with model LastValueNaive in generation 0 of 10
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model SeasonalNaive in generation 0 of 10
# Model Number: 25 with model SeasonalNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model SeasonalNaive in generation 0 of 10
# Model Number: 28 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 28: UnobservedComponents
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 29: UnobservedComponents
# Model Number: 30 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 30: UnobservedComponents
# Model Number: 31 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 31: VAR
# Model Number: 32 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 32: VAR
# Model Number: 33 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 33: VAR
# Model Number: 34 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 34: VECM
# Model Number: 35 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 35: VECM
# Model Number: 36 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 36: VECM
# Model Number: 37 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 37: VECM
# Model Number: 38 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 38: WindowRegression
# Model Number: 39 with model ZeroesNaive in generation 0 of 10
# Model Number: 40 with model ZeroesNaive in generation 0 of 10
# Model Number: 41 with model LastValueNaive in generation 0 of 10
# Model Number: 42 with model AverageValueNaive in generation 0 of 10
# Model Number: 43 with model GLS in generation 0 of 10
# Model Number: 44 with model SeasonalNaive in generation 0 of 10
# Model Number: 45 with model GLM in generation 0 of 10
# Model Number: 46 with model ETS in generation 0 of 10
# Model Number: 47 with model FBProphet in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 47: FBProphet
# Model Number: 48 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 48: GluonTS
# Model Number: 49 with model UnobservedComponents in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 49: UnobservedComponents
# Model Number: 50 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 50: VAR
# Model Number: 51 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 51: VECM
# Model Number: 52 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 52: WindowRegression
# Model Number: 53 with model DatepartRegression in generation 0 of 10
# Model Number: 54 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: TypeError("unsupported operand type(s) for -: 'NoneType' and 'int'") in model 54: UnivariateRegression
# Model Number: 55 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 55: UnivariateMotif
# Model Number: 56 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 56: MultivariateMotif
# Model Number: 57 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (1)') in model 57: SectionalMotif
# Model Number: 58 with model NVAR in generation 0 of 10
# Model Number: 59 with model Theta in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'statsmodels.tsa.forecasting'") in model 59: Theta
# Model Number: 60 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/api.py)") in model 60: ARDL
# Model Number: 61 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 61: UnivariateMotif
# Model Number: 62 with model AverageValueNaive in generation 0 of 10
# Model Number: 63 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 63: UnobservedComponents
# Model Number: 64 with model NVAR in generation 0 of 10
# Model Number: 65 with model DatepartRegression in generation 0 of 10
# Model Number: 66 with model LastValueNaive in generation 0 of 10
# Model Number: 67 with model DatepartRegression in generation 0 of 10
# Epoch 1/50
# 1/1 [==============================] - 6s 6s/step - loss: 0.1173
# Epoch 2/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1385
# Epoch 3/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1186
# Epoch 4/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1231
# Epoch 5/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1281
# Epoch 6/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1300
# Epoch 7/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1200
# Epoch 8/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1251
# Epoch 9/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1224
# Epoch 10/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1301
# Epoch 11/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1434
# Epoch 12/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1178
# Epoch 13/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1272
# Epoch 14/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1281
# Epoch 15/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1231
# Epoch 16/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1283
# Epoch 17/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1207
# Epoch 18/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1262
# Epoch 19/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1276
# Epoch 20/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1378
# Epoch 21/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1094
# Epoch 22/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1152
# Epoch 23/50
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1441
# Epoch 24/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1242
# Epoch 25/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1227
# Epoch 26/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1116
# Epoch 27/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1334
# Epoch 28/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1110
# Epoch 29/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1415
# Epoch 30/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1132
# Epoch 31/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1388
# Epoch 32/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1343
# Epoch 33/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1159
# Epoch 34/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1303
# Epoch 35/50
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1201
# Epoch 36/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1122
# Epoch 37/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1358
# Epoch 38/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1150
# Epoch 39/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1212
# Epoch 40/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1257
# Epoch 41/50
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1426
# Epoch 42/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1267
# Epoch 43/50
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1233
# Epoch 44/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1217
# Epoch 45/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1281
# Epoch 46/50
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1321
# Epoch 47/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1290
# Epoch 48/50
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1313
# Epoch 49/50
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1331
# Epoch 50/50
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1281
# Model Number: 68 with model NVAR in generation 0 of 10
# Model Number: 69 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 69: GluonTS
# Model Number: 70 with model AverageValueNaive in generation 0 of 10
# Model Number: 71 with model DatepartRegression in generation 0 of 10
# Model Number: 72 with model SeasonalNaive in generation 0 of 10
# Model Number: 73 with model VECM in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 73: VECM
# Model Number: 74 with model SeasonalNaive in generation 0 of 10
# Model Number: 75 with model LastValueNaive in generation 0 of 10
# Model Number: 76 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'STL' from 'statsmodels.tsa.seasonal' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py)") in model 76: DatepartRegression
# Model Number: 77 with model DatepartRegression in generation 0 of 10
# Model Number: 78 with model GLS in generation 0 of 10
# Model Number: 79 with model ZeroesNaive in generation 0 of 10
# Model Number: 80 with model GLS in generation 0 of 10
# Model Number: 81 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('Model SectionalMotif returned NaN for one or more series') in model 81: SectionalMotif
# Model Number: 82 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 82: WindowRegression
# Model Number: 83 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 83: VAR
# Model Number: 84 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 84: GluonTS
# Model Number: 85 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 85: UnobservedComponents
# Model Number: 86 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 86: UnivariateRegression
# Model Number: 87 with model ETS in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py:1366: RuntimeWarning:
#
# Mean of empty slice
# Model Number: 88 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 88: ARDL
# Model Number: 89 with model LastValueNaive in generation 0 of 10
# Model Number: 90 with model GLM in generation 0 of 10
# Model Number: 91 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 91: GluonTS
# Model Number: 92 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=5) out of bounds (1)') in model 92: SectionalMotif
# Model Number: 93 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 93: UnobservedComponents
# Model Number: 94 with model ETS in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
# Model Number: 95 with model WindowRegression in generation 0 of 10
# Template Eval Error: KeyError('squared_error') in model 95: WindowRegression
# Model Number: 96 with model GLM in generation 0 of 10
# Model Number: 97 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 97: GluonTS
# Model Number: 98 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 98: GluonTS
# Model Number: 99 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 99: UnivariateMotif
# Model Number: 100 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 100: UnobservedComponents
# Model Number: 101 with model NVAR in generation 0 of 10
# Model Number: 102 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 102: MultivariateMotif
# Model Number: 103 with model ETS in generation 0 of 10
# Model Number: 104 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 104: VAR
# Model Number: 105 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 105: UnobservedComponents
# Model Number: 106 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 106: MultivariateMotif
# Model Number: 107 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('kth(=1) out of bounds (1)') in model 107: SectionalMotif
# Model Number: 108 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 108: VECM
# Model Number: 109 with model NVAR in generation 0 of 10
# Model Number: 110 with model LastValueNaive in generation 0 of 10
# Model Number: 111 with model FBProphet in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 111: FBProphet
# Model Number: 112 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('Model SectionalMotif returned NaN for one or more series') in model 112: SectionalMotif
# Model Number: 113 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError('Model SectionalMotif returned NaN for one or more series') in model 113: SectionalMotif
# Model Number: 114 with model ETS in generation 0 of 10
# Model Number: 115 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 115: WindowRegression
# Model Number: 116 with model NVAR in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py:1366: RuntimeWarning:
#
# Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:380: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:163: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py:1366: RuntimeWarning:
#
# Mean of empty slice
# Model Number: 117 with model LastValueNaive in generation 0 of 10
# Model Number: 118 with model GLS in generation 0 of 10
# Model Number: 119 with model GLS in generation 0 of 10
# Model Number: 120 with model GLS in generation 0 of 10
# Model Number: 121 with model Theta in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'statsmodels.tsa.forecasting'") in model 121: Theta
# Model Number: 122 with model GLM in generation 0 of 10
# Model Number: 123 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: TypeError("unsupported operand type(s) for -: 'NoneType' and 'int'") in model 123: UnivariateRegression
# Model Number: 124 with model LastValueNaive in generation 0 of 10
# Model Number: 125 with model NVAR in generation 0 of 10
# Model Number: 126 with model FBProphet in generation 0 of 10
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# Model Number: 127 with model NVAR in generation 0 of 10
# Model Number: 128 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 128: VECM
# Model Number: 129 with model GLS in generation 0 of 10
# Model Number: 130 with model ZeroesNaive in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'STL' from 'statsmodels.tsa.seasonal' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py)") in model 130: ZeroesNaive
# Model Number: 131 with model MultivariateMotif in generation 0 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 131: MultivariateMotif
# Model Number: 132 with model ETS in generation 0 of 10
# Model Number: 133 with model ETS in generation 0 of 10
# Model Number: 134 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 134: GluonTS
# Model Number: 135 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 135: WindowRegression
# Model Number: 136 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'STL' from 'statsmodels.tsa.seasonal' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py)") in model 136: SectionalMotif
# Model Number: 137 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 137: VECM
# Model Number: 138 with model ZeroesNaive in generation 0 of 10
# Model Number: 139 with model SeasonalNaive in generation 0 of 10
# Model Number: 140 with model AverageValueNaive in generation 0 of 10
# Model Number: 141 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 141: GLM
# Model Number: 142 with model Theta in generation 0 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'statsmodels.tsa.forecasting'") in model 142: Theta
# Model Number: 143 with model AverageValueNaive in generation 0 of 10
# Model Number: 144 with model ZeroesNaive in generation 0 of 10
# New Generation: 1 of 10
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/links.py:521: RuntimeWarning:
#
# overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:134: RuntimeWarning:
#
# invalid value encountered in multiply
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:1163: RuntimeWarning:
#
# invalid value encountered in multiply
# Model Number: 145 with model DatepartRegression in generation 1 of 10
# Model Number: 146 with model DatepartRegression in generation 1 of 10
# Template Eval Error: KeyError('squared_error') in model 146: DatepartRegression
# Model Number: 147 with model DatepartRegression in generation 1 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# Model Number: 148 with model NVAR in generation 1 of 10
# Model Number: 149 with model NVAR in generation 1 of 10
# Model Number: 150 with model NVAR in generation 1 of 10
# Model Number: 151 with model NVAR in generation 1 of 10
# Model Number: 152 with model FBProphet in generation 1 of 10
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# Model Number: 153 with model FBProphet in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 153: FBProphet
# Model Number: 154 with model FBProphet in generation 1 of 10
# Model Number: 155 with model FBProphet in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 155: FBProphet
# Model Number: 156 with model GLS in generation 1 of 10
# Model Number: 157 with model GLS in generation 1 of 10
# Model Number: 158 with model GLS in generation 1 of 10
# Model Number: 159 with model GLM in generation 1 of 10
# Model Number: 160 with model GLM in generation 1 of 10
# Model Number: 161 with model GLM in generation 1 of 10
# Model Number: 162 with model GLM in generation 1 of 10
# Model Number: 163 with model ETS in generation 1 of 10
# Model Number: 164 with model ETS in generation 1 of 10
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
# Model Number: 165 with model ETS in generation 1 of 10
# Model Number: 166 with model ETS in generation 1 of 10
# Model Number: 167 with model AverageValueNaive in generation 1 of 10
# Model Number: 168 with model AverageValueNaive in generation 1 of 10
# Template Eval Error: ImportError("cannot import name 'STL' from 'statsmodels.tsa.seasonal' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py)") in model 168: AverageValueNaive
# Model Number: 169 with model AverageValueNaive in generation 1 of 10
# Template Eval Error: ImportError("cannot import name 'STL' from 'statsmodels.tsa.seasonal' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py)") in model 169: AverageValueNaive
# Model Number: 170 with model LastValueNaive in generation 1 of 10
# Model Number: 171 with model LastValueNaive in generation 1 of 10
# Model Number: 172 with model LastValueNaive in generation 1 of 10
# Model Number: 173 with model ZeroesNaive in generation 1 of 10
# Model Number: 174 with model ZeroesNaive in generation 1 of 10
# Model Number: 175 with model SeasonalNaive in generation 1 of 10
# Model Number: 176 with model SeasonalNaive in generation 1 of 10
# Model Number: 177 with model SeasonalNaive in generation 1 of 10
# Model Number: 178 with model SeasonalNaive in generation 1 of 10
# Model Number: 179 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 179: GluonTS
# Model Number: 180 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 180: GluonTS
# Model Number: 181 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 181: GluonTS
# Model Number: 182 with model GluonTS in generation 1 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 182: GluonTS
# Model Number: 183 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 183: UnobservedComponents
# Model Number: 184 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 184: UnobservedComponents
# Model Number: 185 with model UnobservedComponents in generation 1 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 185: UnobservedComponents
# Model Number: 186 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 186: VAR
# Model Number: 187 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 187: VAR
# Model Number: 188 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 188: VAR
# Model Number: 189 with model VAR in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 189: VAR
# Model Number: 190 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 190: VECM
# Model Number: 191 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 191: VECM
# Model Number: 192 with model VECM in generation 1 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 192: VECM
# Model Number: 193 with model WindowRegression in generation 1 of 10
# Model Number: 194 with model WindowRegression in generation 1 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 194: WindowRegression
# Model Number: 195 with model WindowRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 195: WindowRegression
# Model Number: 196 with model UnivariateRegression in generation 1 of 10
# Template Eval Error: TypeError("unsupported operand type(s) for -: 'NoneType' and 'int'") in model 196: UnivariateRegression
# Model Number: 197 with model UnivariateRegression in generation 1 of 10
# Template Eval Error: TypeError("unsupported operand type(s) for -: 'NoneType' and 'int'") in model 197: UnivariateRegression
# Model Number: 198 with model UnivariateRegression in generation 1 of 10
# Template Eval Error: TypeError("unsupported operand type(s) for -: 'NoneType' and 'int'") in model 198: UnivariateRegression
# Model Number: 199 with model UnivariateRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 199: UnivariateRegression
# Model Number: 200 with model UnivariateMotif in generation 1 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 200: UnivariateMotif
# Model Number: 201 with model UnivariateMotif in generation 1 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 201: UnivariateMotif
# Model Number: 202 with model UnivariateMotif in generation 1 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 202: UnivariateMotif
# Model Number: 203 with model UnivariateMotif in generation 1 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 203: UnivariateMotif
# Model Number: 204 with model MultivariateMotif in generation 1 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 204: MultivariateMotif
# Model Number: 205 with model MultivariateMotif in generation 1 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 205: MultivariateMotif
# Model Number: 206 with model MultivariateMotif in generation 1 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 206: MultivariateMotif
# Model Number: 207 with model MultivariateMotif in generation 1 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 207: MultivariateMotif
# Model Number: 208 with model SectionalMotif in generation 1 of 10
# Template Eval Error: ValueError('Model SectionalMotif returned NaN for one or more series') in model 208: SectionalMotif
# Model Number: 209 with model SectionalMotif in generation 1 of 10
# Template Eval Error: ValueError('Model SectionalMotif returned NaN for one or more series') in model 209: SectionalMotif
# Model Number: 210 with model SectionalMotif in generation 1 of 10
# Template Eval Error: ValueError('kth(=10) out of bounds (1)') in model 210: SectionalMotif
# Model Number: 211 with model SectionalMotif in generation 1 of 10
# Template Eval Error: ValueError('Model SectionalMotif returned NaN for one or more series') in model 211: SectionalMotif
# Model Number: 212 with model Theta in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'statsmodels.tsa.forecasting'") in model 212: Theta
# Model Number: 213 with model Theta in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'statsmodels.tsa.forecasting'") in model 213: Theta
# Model Number: 214 with model Theta in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'statsmodels.tsa.forecasting'") in model 214: Theta
# Model Number: 215 with model Theta in generation 1 of 10
# Template Eval Error: ModuleNotFoundError("No module named 'statsmodels.tsa.forecasting'") in model 215: Theta
# Model Number: 216 with model ARDL in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 216: ARDL
# Model Number: 217 with model ARDL in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 217: ARDL
# Model Number: 218 with model ARDL in generation 1 of 10
# Template Eval Error: ImportError("cannot import name 'STL' from 'statsmodels.tsa.seasonal' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/seasonal.py)") in model 218: ARDL
# Model Number: 219 with model ARDL in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 219: ARDL
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py:1366: RuntimeWarning:
#
# Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py:1366: RuntimeWarning:
#
# Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/autots/models/basics.py:1860: RuntimeWarning:
#
# Mean of empty slice
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py:1366: RuntimeWarning:
#
# Mean of empty slice
# New Generation: 2 of 10
# Model Number: 220 with model DatepartRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 220: DatepartRegression
# Model Number: 221 with model DatepartRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 221: DatepartRegression
# Model Number: 222 with model DatepartRegression in generation 2 of 10
# Model Number: 223 with model NVAR in generation 2 of 10
# Model Number: 224 with model NVAR in generation 2 of 10
# Model Number: 225 with model NVAR in generation 2 of 10
# Model Number: 226 with model NVAR in generation 2 of 10
# Template Eval Error: IndexError('index -12 is out of bounds for axis 1 with size 11') in model 226: NVAR
# Model Number: 227 with model FBProphet in generation 2 of 10
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# Model Number: 228 with model FBProphet in generation 2 of 10
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# Model Number: 229 with model FBProphet in generation 2 of 10
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# Model Number: 230 with model FBProphet in generation 2 of 10
# Model Number: 231 with model GLS in generation 2 of 10
# Model Number: 232 with model GLS in generation 2 of 10
# Model Number: 233 with model GLS in generation 2 of 10
# Model Number: 234 with model GLM in generation 2 of 10
# Model Number: 235 with model GLM in generation 2 of 10
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 235: GLM
# Model Number: 236 with model GLM in generation 2 of 10
# Model Number: 237 with model GLM in generation 2 of 10
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:428: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:134: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
# Model Number: 238 with model ETS in generation 2 of 10
# Model Number: 239 with model ETS in generation 2 of 10
# Model Number: 240 with model ETS in generation 2 of 10
# Model Number: 241 with model ETS in generation 2 of 10
# Model Number: 242 with model WindowRegression in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 242: WindowRegression
# Model Number: 243 with model WindowRegression in generation 2 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 243: WindowRegression
# Model Number: 244 with model WindowRegression in generation 2 of 10
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 244: WindowRegression
# Model Number: 245 with model AverageValueNaive in generation 2 of 10
# Model Number: 246 with model AverageValueNaive in generation 2 of 10
# Model Number: 247 with model AverageValueNaive in generation 2 of 10
# Model Number: 248 with model LastValueNaive in generation 2 of 10
# Model Number: 249 with model LastValueNaive in generation 2 of 10
# Model Number: 250 with model LastValueNaive in generation 2 of 10
# Model Number: 251 with model ZeroesNaive in generation 2 of 10
# Model Number: 252 with model ZeroesNaive in generation 2 of 10
# Model Number: 253 with model ZeroesNaive in generation 2 of 10
# Model Number: 254 with model SeasonalNaive in generation 2 of 10
# Model Number: 255 with model SeasonalNaive in generation 2 of 10
# Model Number: 256 with model SeasonalNaive in generation 2 of 10
# Model Number: 257 with model SeasonalNaive in generation 2 of 10
# Model Number: 258 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 258: GluonTS
# Model Number: 259 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 259: GluonTS
# Model Number: 260 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 260: GluonTS
# Model Number: 261 with model GluonTS in generation 2 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 261: GluonTS
# Model Number: 262 with model UnobservedComponents in generation 2 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 262: UnobservedComponents
# Model Number: 263 with model UnobservedComponents in generation 2 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 263: UnobservedComponents
# Model Number: 264 with model UnobservedComponents in generation 2 of 10
# Template Eval Error: TypeError('issubclass() arg 2 must be a class or tuple of classes') in model 264: UnobservedComponents
# Model Number: 265 with model VAR in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 265: VAR
# Model Number: 266 with model VAR in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 266: VAR
# Model Number: 267 with model VAR in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 267: VAR
# Model Number: 268 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 268: VECM
# Model Number: 269 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 269: VECM
# Model Number: 270 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 270: VECM
# Model Number: 271 with model VECM in generation 2 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 271: VECM
# Model Number: 272 with model UnivariateRegression in generation 2 of 10
# Template Eval Error: TypeError("unsupported operand type(s) for -: 'NoneType' and 'int'") in model 272: UnivariateRegression
# Model Number: 273 with model UnivariateRegression in generation 2 of 10
# Template Eval Error: TypeError("unsupported operand type(s) for -: 'NoneType' and 'int'") in model 273: UnivariateRegression
# Model Number: 274 with model UnivariateRegression in generation 2 of 10
# Template Eval Error: TypeError("unsupported operand type(s) for -: 'NoneType' and 'int'") in model 274: UnivariateRegression
# Model Number: 275 with model UnivariateRegression in generation 2 of 10
# Template Eval Error: TypeError("unsupported operand type(s) for -: 'NoneType' and 'int'") in model 275: UnivariateRegression
# Model Number: 276 with model UnivariateMotif in generation 2 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 276: UnivariateMotif
# Model Number: 277 with model UnivariateMotif in generation 2 of 10
# Template Eval Error: AttributeError("module 'numpy.lib.stride_tricks' has no attribute 'sliding_window_view'") in model 277: UnivariateMotif
# Model Number: 278 with model UnivariateMotif in generation 2 of 10
# ...
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# 13 - FBProphet with avg smape 94.92:
# Model Number: 14 of 95 with model FBProphet for Validation 2
# 14 - FBProphet with avg smape 94.92:
# Model Number: 15 of 95 with model ETS for Validation 2
# 15 - ETS with avg smape 96.75:
# Model Number: 16 of 95 with model ZeroesNaive for Validation 2
# 16 - ZeroesNaive with avg smape 94.92:
# Model Number: 17 of 95 with model ETS for Validation 2
# 17 - ETS with avg smape 96.75:
# Model Number: 18 of 95 with model ETS for Validation 2
# 18 - ETS with avg smape 96.75:
# Model Number: 19 of 95 with model ZeroesNaive for Validation 2
# 19 - ZeroesNaive with avg smape 94.92:
# Model Number: 20 of 95 with model ETS for Validation 2
# 20 - ETS with avg smape 96.75:
# Model Number: 21 of 95 with model ETS for Validation 2
# 21 - ETS with avg smape 96.75:
# Model Number: 22 of 95 with model ZeroesNaive for Validation 2
# 22 - ZeroesNaive with avg smape 94.92:
# Model Number: 23 of 95 with model ETS for Validation 2
# 23 - ETS with avg smape 96.75:
# Model Number: 24 of 95 with model ZeroesNaive for Validation 2
# 24 - ZeroesNaive with avg smape 102.41:
# Model Number: 25 of 95 with model GLS for Validation 2
# 25 - GLS with avg smape 94.92:
# Model Number: 26 of 95 with model GLS for Validation 2
# 26 - GLS with avg smape 94.92:
# Model Number: 27 of 95 with model GLS for Validation 2
# 27 - GLS with avg smape 94.92:
# Model Number: 28 of 95 with model GLS for Validation 2
# 28 - GLS with avg smape 94.92:
# Model Number: 29 of 95 with model GLS for Validation 2
# 29 - GLS with avg smape 94.92:
# Model Number: 30 of 95 with model GLM for Validation 2
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 30: GLM
# Model Number: 31 of 95 with model AverageValueNaive for Validation 2
# 31 - AverageValueNaive with avg smape 94.92:
# Model Number: 32 of 95 with model GLS for Validation 2
# 32 - GLS with avg smape 94.92:
# Model Number: 33 of 95 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 33: NVAR
# Model Number: 34 of 95 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 34: NVAR
# Model Number: 35 of 95 with model ETS for Validation 2
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:179: RuntimeWarning:
#
# invalid value encountered in true_divide
# 35 - ETS with avg smape 94.92:
# Model Number: 36 of 95 with model ETS for Validation 2
# 36 - ETS with avg smape 94.92:
# Model Number: 37 of 95 with model DatepartRegression for Validation 2
# 37 - DatepartRegression with avg smape 191.55:
# Model Number: 38 of 95 with model DatepartRegression for Validation 2
# 38 - DatepartRegression with avg smape 100.64:
# Model Number: 39 of 95 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 39: NVAR
# Model Number: 40 of 95 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 40: NVAR
# Model Number: 41 of 95 with model FBProphet for Validation 2
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# 41 - FBProphet with avg smape 191.55:
# Model Number: 42 of 95 with model FBProphet for Validation 2
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# 42 - FBProphet with avg smape 191.55:
# Model Number: 43 of 95 with model FBProphet for Validation 2
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# 43 - FBProphet with avg smape 191.55:
# Model Number: 44 of 95 with model FBProphet for Validation 2
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# 44 - FBProphet with avg smape 191.55:
# Model Number: 45 of 95 with model FBProphet for Validation 2
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# 45 - FBProphet with avg smape 191.55:
# Model Number: 46 of 95 with model FBProphet for Validation 2
# 46 - FBProphet with avg smape 191.55:
# Model Number: 47 of 95 with model AverageValueNaive for Validation 2
# 47 - AverageValueNaive with avg smape 104.49:
# Model Number: 48 of 95 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 48: NVAR
# Model Number: 49 of 95 with model AverageValueNaive for Validation 2
# 49 - AverageValueNaive with avg smape 101.77:
# Model Number: 50 of 95 with model AverageValueNaive for Validation 2
# 50 - AverageValueNaive with avg smape 101.94:
# Model Number: 51 of 95 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 51: NVAR
# Model Number: 52 of 95 with model LastValueNaive for Validation 2
# 52 - LastValueNaive with avg smape 94.92:
# Model Number: 53 of 95 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 53: WindowRegression
# Model Number: 54 of 95 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 54: NVAR
# Model Number: 55 of 95 with model NVAR for Validation 2
# Template Eval Error: IndexError('index -4 is out of bounds for axis 1 with size 3') in model 55: NVAR
# Model Number: 56 of 95 with model GLS for Validation 2
# 56 - GLS with avg smape 94.92:
# Model Number: 57 of 95 with model LastValueNaive for Validation 2
# 57 - LastValueNaive with avg smape 94.92:
# Model Number: 58 of 95 with model LastValueNaive for Validation 2
# 58 - LastValueNaive with avg smape 94.92:
# Model Number: 59 of 95 with model AverageValueNaive for Validation 2
# 59 - AverageValueNaive with avg smape 191.55:
# Model Number: 60 of 95 with model SeasonalNaive for Validation 2
# 60 - SeasonalNaive with avg smape 94.92:
# Model Number: 61 of 95 with model GLS for Validation 2
# 61 - GLS with avg smape 94.92:
# Model Number: 62 of 95 with model SeasonalNaive for Validation 2
# 62 - SeasonalNaive with avg smape 94.92:
# Model Number: 63 of 95 with model GLM for Validation 2
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 63: GLM
# Model Number: 64 of 95 with model ZeroesNaive for Validation 2
# 64 - ZeroesNaive with avg smape 94.92:
# Model Number: 65 of 95 with model ZeroesNaive for Validation 2
# Template Eval Error: ValueError('NaN in DifferencedTransformer.inverse_transform') in model 65: ZeroesNaive
# Model Number: 66 of 95 with model GLM for Validation 2
# 66 - GLM with avg smape 94.92:
# Model Number: 67 of 95 with model GLM for Validation 2
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:179: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py:765: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py:706: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice.
# 67 - GLM with avg smape 94.92:
# Model Number: 68 of 95 with model LastValueNaive for Validation 2
# 68 - LastValueNaive with avg smape 133.54:
# Model Number: 69 of 95 with model GLM for Validation 2
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 69: GLM
# Model Number: 70 of 95 with model GLM for Validation 2
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 70: GLM
# Model Number: 71 of 95 with model GLM for Validation 2
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 71: GLM
# Model Number: 72 of 95 with model GLM for Validation 2
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 72: GLM
# Model Number: 73 of 95 with model SeasonalNaive for Validation 2
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:179: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:179: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:179: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:273: DomainWarning:
#
# The inverse_power link function does not respect the domain of the Gamma family.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:179: RuntimeWarning:
#
# invalid value encountered in true_divide
# 73 - SeasonalNaive with avg smape 94.92:
# Model Number: 74 of 95 with model ZeroesNaive for Validation 2
# 74 - ZeroesNaive with avg smape 94.92:
# Model Number: 75 of 95 with model AverageValueNaive for Validation 2
# 75 - AverageValueNaive with avg smape 94.92:
# Model Number: 76 of 95 with model AverageValueNaive for Validation 2
# 76 - AverageValueNaive with avg smape 191.55:
# Model Number: 77 of 95 with model AverageValueNaive for Validation 2
# 77 - AverageValueNaive with avg smape 191.55:
# Model Number: 78 of 95 with model DatepartRegression for Validation 2
# 78 - DatepartRegression with avg smape 93.77:
# Model Number: 79 of 95 with model DatepartRegression for Validation 2
# 79 - DatepartRegression with avg smape 93.77:
# Model Number: 80 of 95 with model DatepartRegression for Validation 2
# 80 - DatepartRegression with avg smape 93.76:
# Model Number: 81 of 95 with model DatepartRegression for Validation 2
# 81 - DatepartRegression with avg smape 200.0:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py:2982: RuntimeWarning:
#
# divide by zero encountered in log
# Model Number: 82 of 95 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 82: WindowRegression
# Model Number: 83 of 95 with model DatepartRegression for Validation 2
# 83 - DatepartRegression with avg smape 191.55:
# Model Number: 84 of 95 with model LastValueNaive for Validation 2
# 84 - LastValueNaive with avg smape 133.54:
# Model Number: 85 of 95 with model LastValueNaive for Validation 2
# 85 - LastValueNaive with avg smape 191.55:
# Model Number: 86 of 95 with model LastValueNaive for Validation 2
# 86 - LastValueNaive with avg smape 133.54:
# Model Number: 87 of 95 with model ZeroesNaive for Validation 2
# 87 - ZeroesNaive with avg smape 100.38:
# Model Number: 88 of 95 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 88: WindowRegression
# Model Number: 89 of 95 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 89: WindowRegression
# Model Number: 90 of 95 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 90: WindowRegression
# Model Number: 91 of 95 with model DatepartRegression for Validation 2
# 91 - DatepartRegression with avg smape 191.55:
# Model Number: 92 of 95 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 92: WindowRegression
# Model Number: 93 of 95 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 93: WindowRegression
# Model Number: 94 of 95 with model UnobservedComponents for Validation 2
# Template Eval Error: LinAlgError('Non-positive-definite forecast error covariance matrix encountered at period 2') in model 94: UnobservedComponents
# Model Number: 95 of 95 with model WindowRegression for Validation 2
# Template Eval Error: ValueError('Found array with 0 sample(s) (shape=(0, 0)) while a minimum of 1 is required.') in model 95: WindowRegression

# %%
print(forecast)
# Out:
#             followers_gained
# 2021-08-31        577.466667
# 2021-09-30        613.933333
# 2021-10-31        650.400000
# 2021-11-30        686.866667
